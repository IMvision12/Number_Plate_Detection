# %%
import pandas as pd
import tensorflow as tf
import yaml
import os
from sklearn import model_selection
import numpy as np
from tqdm import tqdm
import shutil

# %%
shutil.copytree("../input/yolov5/yolov5-master","/kaggle/working/yolov5-master")
shutil.copytree("../input/yolov5-number-plate/Dataset","/kaggle/working/Dataset/")
shutil.copytree("../input/test-data/images","/kaggle/working/images/")
# Out:
# '/kaggle/working/images/'

# %%
cwd = '/kaggle/working/'

data = dict(
    train =  "/kaggle/working/Dataset/images/train" ,
    val   =  "/kaggle/working/Dataset/images/val",
    nc    = 1,
    names = ['license_plate']
    )

with open('/kaggle/working/data.yaml', 'w') as outfile:
    yaml.dump(data, outfile, default_flow_style=False)

f = open('/kaggle/working/data.yaml', 'r')
print('\nyaml:')
print(f.read())
# Out:
# yaml:
# names:
# - license_plate
# nc: 1
# train: /kaggle/working/Dataset/images/train
# val: /kaggle/working/Dataset/images/val

# %%
os.chdir('/kaggle/working/yolov5-master')

import torch
from IPython.display import Image, clear_output 
clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.9.1 _CudaDeviceProperties(name='Tesla P100-PCIE-16GB', major=6, minor=0, total_memory=16280MB, multi_processor_count=56)

# %%
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %%
# !WANDB_MODE="dryrun" python train.py --img 640 --batch 3 --epochs 25 --data /kaggle/working/data.yaml --weights yolov5n6.pt --cache
# Out:
# ...
# train: weights=yolov5n6.pt, cfg=, data=/kaggle/working/data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=25, batch_size=3, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 2022-2-3 torch 1.9.1 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# ...

# %%
cd ..
# Out:
# /kaggle/working

# %%
# !WANDB_MODE="dryrun" python /kaggle/working/yolov5-master/detect.py --weights /kaggle/working/yolov5-master/runs/train/exp/weights/best.pt --source "./images/"
# Out:
# detect: weights=['/kaggle/working/yolov5-master/runs/train/exp/weights/best.pt'], source=./images/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5-master/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-2-3 torch 1.9.1 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model Summary: 280 layers, 3087256 parameters, 0 gradients
# image 1/169 /kaggle/working/images/car_100.jpg: 512x640 Done. (0.022s)
# image 2/169 /kaggle/working/images/car_104.jpg: 320x640 Done. (0.022s)
# image 3/169 /kaggle/working/images/car_108.jpg: 448x640 Done. (0.024s)
# image 4/169 /kaggle/working/images/car_120.jpg: 384x640 1 license_plate, Done. (0.023s)
# ...
